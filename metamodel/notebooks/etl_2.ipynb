# %%
import pandas as pd
import os

# %%
SCRIPT_DIR_PATH = os.getcwd()
ROOT_DIR_PATH = os.path.dirname(SCRIPT_DIR_PATH)
DATA_DIR_PATH = os.path.join(ROOT_DIR_PATH, "data")
MAPPING_DIR_PATH = os.path.join(DATA_DIR_PATH, "mapping")
PREDICTORS_DIR_PATH = os.path.join(DATA_DIR_PATH, "predictors")
SSP_DIR_PATH = os.path.join(DATA_DIR_PATH, "ssp")
SIMULATION_DIR_PATH = os.path.join(SSP_DIR_PATH, "sisepuede_run_2025-01-14T17;04;06.975301_output_database")
TRAINING_DIR_PATH = os.path.join(DATA_DIR_PATH, "training")

# %%
lhc_trials_df = pd.read_csv(os.path.join(PREDICTORS_DIR_PATH, "lhs_sample_group_experiments.csv"))
lhc_trials_df
# Out:
#             1         2         3         4         5         6         7  \
# 0    0.952436  0.360397  0.202990  0.995748  0.369859  0.919920  0.478450
# 1    0.304955  0.204875  0.540658  0.800192  0.206396  0.777352  0.805727
# 2    0.609262  0.366443  0.601808  0.916668  0.386475  0.181162  0.138910
# 3    0.815313  0.487444  0.323954  0.634299  0.064625  0.926815  0.633805
# 4    0.973878  0.842718  0.884382  0.483039  0.455502  0.003343  0.571994
# ..        ...       ...       ...       ...       ...       ...       ...
# 995  0.218189  0.886941  0.569155  0.107766  0.955775  0.380014  0.569711
# 996  0.510025  0.235856  0.847465  0.138888  0.182086  0.453749  0.242018
# 997  0.276479  0.612911  0.642697  0.952037  0.176638  0.411246  0.169671
# 998  0.600573  0.553323  0.306380  0.464389  0.834916  0.786519  0.717580
# 999  0.164542  0.057579  0.648085  0.210240  0.441924  0.364614  0.031031
#
#             8         9        10  ...      1472      1473      1474  \
# 0    0.445798  0.490988  0.510280  ...  0.985425  0.482783  0.183188
# 1    0.536048  0.779857  0.623335  ...  0.437877  0.149747  0.308130
# 2    0.768925  0.884425  0.232722  ...  0.360238  0.348950  0.165501
# 3    0.439346  0.027114  0.532020  ...  0.060470  0.660562  0.621883
# 4    0.108021  0.346714  0.892123  ...  0.910718  0.621574  0.244454
# ..        ...       ...       ...  ...       ...       ...       ...
# 995  0.312233  0.791412  0.300450  ...  0.669261  0.883331  0.431040
# 996  0.215693  0.657012  0.808412  ...  0.538035  0.037013  0.528031
# 997  0.694365  0.606286  0.678398  ...  0.262631  0.657597  0.243538
# 998  0.168263  0.009808  0.855097  ...  0.069343  0.293393  0.632635
# 999  0.873487  0.951080  0.509441  ...  0.486452  0.115074  0.989445
#
#          1475      1476      1477      1478      1480      1481  future_id
# 0    0.364889  0.005297  0.223598  0.927810  0.036368  0.933822          1
# 1    0.780839  0.784662  0.742266  0.147130  0.081654  0.491202          2
# 2    0.813845  0.950005  0.342632  0.053104  0.316417  0.173655          3
# 3    0.911838  0.030974  0.912003  0.150989  0.246583  0.353195          4
# 4    0.927056  0.561529  0.611280  0.552761  0.125694  0.147930          5
# ..        ...       ...       ...       ...       ...       ...        ...
# 995  0.045121  0.790492  0.081530  0.351688  0.746613  0.853002        996
# 996  0.079728  0.918024  0.653280  0.161674  0.033243  0.257661        997
# 997  0.603350  0.377625  0.316224  0.615736  0.996441  0.704642        998
# 998  0.168413  0.611178  0.295950  0.813797  0.934377  0.473035        999
# 999  0.965431  0.352193  0.278569  0.164544  0.144563  0.306248       1000
#
# [1000 rows x 85 columns]

# %%
la_emissions_df = pd.read_csv(os.path.join(SIMULATION_DIR_PATH, "WIDE_INPUTS_OUTPUTS.csv"))
la_emissions_df
# Out:
#        primary_id     region  time_period  area_agrc_crops_bevs_and_spices  \
# 0          275275  louisiana            7                                0
# 1          275275  louisiana            8                                0
# 2          275275  louisiana            9                                0
# 3          275275  louisiana           10                                0
# 4          275275  louisiana           11                                0
# ...           ...        ...          ...                              ...
# 28560      275293  louisiana           31                                0
# 28561      275293  louisiana           32                                0
# 28562      275293  louisiana           33                                0
# 28563      275293  louisiana           34                                0
# 28564      275293  louisiana           35                                0
#
#        area_agrc_crops_cereals  area_agrc_crops_fibers  \
# 0                352056.299497            65286.215373
# 1                349848.854439            64876.861148
# 2                347657.028850            64470.403437
# 3                345480.707102            64066.820799
# 4                343319.774453            63666.091953
# ...                        ...                     ...
# 28560            294221.428184            63220.177553
# 28561            292599.377554            63909.784176
# 28562            291148.417580            64642.940250
# 28563            289866.317272            65408.965880
# 28564            288750.123258            66197.018891
#
#        area_agrc_crops_fruits  \
# 0                   76.761572
# 1                   76.280265
# 2                   75.802365
# 3                   75.327844
# 4                   74.856679
# ...                       ...
# 28560               89.937159
# 28561               92.081486
# 28562               94.277370
# 28563               96.504382
# 28564               98.742234
#
#        area_agrc_crops_herbs_and_other_perennial_crops  area_agrc_crops_nuts  \
# 0                                         75770.572219           6423.938390
# 1                                         75295.479526           6383.659346
# 2                                         74823.748501           6343.665309
# 3                                         74355.354257           6303.954170
# 4                                         73890.272100           6264.523834
# ...                                                ...                   ...
# 28560                                     81027.978802          16195.145410
# 28561                                     82305.169476          17949.679259
# 28562                                     83613.385961          19878.507594
# 28563                                     84938.693208          21970.474633
# 28564                                     86267.472804          24204.753673
#
#        area_agrc_crops_other_annual  ...  yf_agrc_fruits_tonne_ha  \
# 0                      1.104616e+06  ...                18.989020
# 1                      1.097689e+06  ...                18.791974
# 2                      1.090812e+06  ...                18.594927
# 3                      1.083984e+06  ...                18.397880
# 4                      1.077204e+06  ...                18.200833
# ...                             ...  ...                      ...
# 28560                  1.078609e+06  ...                15.352838
# 28561                  1.087869e+06  ...                15.332242
# 28562                  1.097669e+06  ...                15.323540
# 28563                  1.107899e+06  ...                15.326730
# 28564                  1.118450e+06  ...                15.341813
#
#        yf_agrc_herbs_and_other_perennial_crops_tonne_ha  \
# 0                                             11.831723
# 1                                             11.736001
# 2                                             11.640280
# 3                                             11.544559
# 4                                             11.448838
# ...                                                 ...
# 28560                                         10.364332
# 28561                                         10.370063
# 28562                                         10.381572
# 28563                                         10.398858
# 28564                                         10.421921
#
#        yf_agrc_nuts_tonne_ha  yf_agrc_other_annual_tonne_ha  \
# 0                   2.782454                       6.177415
# 1                   2.699011                       5.189029
# 2                   2.615567                       6.319971
# 3                   2.532124                       6.299606
# 4                   2.448681                       6.279241
# ...                      ...                            ...
# 28560               0.639586                       6.489255
# 28561               0.599125                       6.513671
# 28562               0.563700                       6.539317
# 28563               0.533311                       6.566192
# 28564               0.507959                       6.594296
#
#        yf_agrc_other_woody_perennial_tonne_ha  yf_agrc_pulses_tonne_ha  \
# 0                                           0                 3.474771
# 1                                           0                 2.688411
# 2                                           0                 3.416092
# 3                                           0                 3.415907
# 4                                           0                 3.415722
# ...                                       ...                      ...
# 28560                                       0                 3.802796
# 28561                                       0                 3.823289
# 28562                                       0                 3.843794
# 28563                                       0                 3.864310
# 28564                                       0                 3.884837
#
#        yf_agrc_rice_tonne_ha  yf_agrc_sugar_cane_tonne_ha  \
# 0                   8.253027                    87.719298
# 1                   8.475414                    83.271559
# 2                   8.422668                    89.334930
# 3                   8.422736                    90.402061
# 4                   8.422804                    91.469193
# ...                      ...                          ...
# 28560               9.390390                   128.685483
# 28561               9.441271                   129.944000
# 28562               9.492147                   131.138110
# 28563               9.543020                   132.267813
# 28564               9.593889                   133.333109
#
#        yf_agrc_tubers_tonne_ha  yf_agrc_vegetables_and_vines_tonne_ha
# 0                    41.144328                              31.476288
# 1                    41.748977                              31.761360
# 2                    42.353627                              32.046432
# 3                    42.958276                              32.331504
# 4                    43.562926                              32.616576
# ...                        ...                                    ...
# 28560                63.702379                              43.496713
# 28561                64.365588                              43.882292
# 28562                64.992304                              44.250665
# 28563                65.582526                              44.601833
# 28564                66.136254                              44.935795
#
# [28565 rows x 3669 columns]

# %% [markdown]
# ## Transform emissions time series data in target variables

# %%
subsector_totals_cols = [col for col in la_emissions_df.columns if "emission_co2e_subsector_total" in col]
subsector_totals_cols
# Out:
# ['emission_co2e_subsector_total_agrc',
#  'emission_co2e_subsector_total_ccsq',
#  'emission_co2e_subsector_total_entc',
#  'emission_co2e_subsector_total_fgtv',
#  'emission_co2e_subsector_total_frst',
#  'emission_co2e_subsector_total_inen',
#  'emission_co2e_subsector_total_ippu',
#  'emission_co2e_subsector_total_lndu',
#  'emission_co2e_subsector_total_lsmm',
#  'emission_co2e_subsector_total_lvst',
#  'emission_co2e_subsector_total_scoe',
#  'emission_co2e_subsector_total_soil',
#  'emission_co2e_subsector_total_trns',
#  'emission_co2e_subsector_total_trww',
#  'emission_co2e_subsector_total_waso']

# %%
# Filter the la_emissions_df to only include the subsector totals
la_emissions_subsector_totals_df = la_emissions_df[["primary_id", "time_period"] + subsector_totals_cols]
la_emissions_subsector_totals_df.head()
# Out:
#    primary_id  time_period  emission_co2e_subsector_total_agrc  \
# 0      275275            7                            2.923974
# 1      275275            8                            2.857986
# 2      275275            9                            2.899699
# 3      275275           10                            2.882666
# 4      275275           11                            2.865747
#
#    emission_co2e_subsector_total_ccsq  emission_co2e_subsector_total_entc  \
# 0                                 0.0                           30.469259
# 1                                 0.0                           28.476065
# 2                                 0.0                           34.882828
# 3                                 0.0                           35.016651
# 4                                 0.0                           35.168961
#
#    emission_co2e_subsector_total_fgtv  emission_co2e_subsector_total_frst  \
# 0                           13.094104                          -36.545088
# 1                           11.929561                          -38.817968
# 2                           15.633156                          -40.622482
# 3                           15.680324                          -42.118513
# 4                           15.736519                          -43.406884
#
#    emission_co2e_subsector_total_inen  emission_co2e_subsector_total_ippu  \
# 0                          117.042622                            2.629950
# 1                          114.193574                            2.640618
# 2                          113.969034                            2.653297
# 3                          112.576725                            2.667916
# 4                          111.119217                            2.684396
#
#    emission_co2e_subsector_total_lndu  emission_co2e_subsector_total_lsmm  \
# 0                            2.050000                            0.230319
# 1                            2.057088                            0.230824
# 2                            2.064100                            0.231385
# 3                            2.071038                            0.231985
# 4                            2.077902                            0.232615
#
#    emission_co2e_subsector_total_lvst  emission_co2e_subsector_total_scoe  \
# 0                            1.539811                            4.491483
# 1                            1.533068                            4.525427
# 2                            1.526359                            4.561015
# 3                            1.519683                            4.598400
# 4                            1.513040                            4.637649
#
#    emission_co2e_subsector_total_soil  emission_co2e_subsector_total_trns  \
# 0                            1.233181                           45.130223
# 1                            1.242080                           45.862823
# 2                            1.247478                           46.693347
# 3                            1.249169                           47.602613
# 4                            1.247322                           48.575658
#
#    emission_co2e_subsector_total_trww  emission_co2e_subsector_total_waso
# 0                            0.447204                            3.138402
# 1                            0.454013                            3.187628
# 2                            0.461144                            3.238212
# 3                            0.468528                            3.289838
# 4                            0.476114                            3.342286

# %%
la_emissions_subsector_totals_df.describe()
# Out:
#           primary_id   time_period  emission_co2e_subsector_total_agrc  \
# count   28565.000000  28565.000000                        28565.000000
# mean   275776.930964     21.000000                            2.845071
# std       289.184625      8.366747                            0.215033
# min    275275.000000      7.000000                            1.925236
# 25%    275528.000000     14.000000                            2.743323
# 50%    275778.000000     21.000000                            2.848941
# 75%    276027.000000     28.000000                            2.914676
# max    276275.000000     35.000000                            3.926774
#
#        emission_co2e_subsector_total_ccsq  emission_co2e_subsector_total_entc  \
# count                        28565.000000                        28565.000000
# mean                            -7.080496                           23.309183
# std                              7.125260                            9.860684
# min                            -31.089497                            0.133390
# 25%                            -11.281351                           15.028673
# 50%                             -4.948256                           24.917182
# 75%                             -0.951165                           31.583779
# max                              0.000000                           53.569704
#
#        emission_co2e_subsector_total_fgtv  emission_co2e_subsector_total_frst  \
# count                        2.856500e+04                        28565.000000
# mean                         2.569790e+05                          -46.271465
# std                          6.620617e+06                            5.046281
# min                          6.826294e-01                          -64.731343
# 25%                          5.911870e+00                          -49.022699
# 50%                          9.626622e+00                          -45.551354
# 75%                          1.309410e+01                          -43.343442
# max                          2.500749e+08                          -35.892389
#
#        emission_co2e_subsector_total_inen  emission_co2e_subsector_total_ippu  \
# count                        28565.000000                        28565.000000
# mean                            66.425101                            2.242980
# std                             32.415229                            0.409276
# min                              1.657513                            0.415510
# 25%                             38.545754                            1.979404
# 50%                             61.451085                            2.339809
# 75%                             97.343346                            2.629950
# max                            117.042622                            2.805758
#
#        emission_co2e_subsector_total_lndu  emission_co2e_subsector_total_lsmm  \
# count                        28565.000000                        28565.000000
# mean                             1.406896                            0.209375
# std                              0.593358                            0.029369
# min                              0.001909                            0.065987
# 25%                              0.924817                            0.194176
# 50%                              1.510359                            0.221758
# 75%                              1.998539                            0.231385
# max                              2.603428                            0.258216
#
#        emission_co2e_subsector_total_lvst  emission_co2e_subsector_total_scoe  \
# count                        28565.000000                        28565.000000
# mean                             1.395541                            3.560940
# std                              0.160350                            1.080701
# min                              0.707178                            0.000000
# 25%                              1.306573                            2.901117
# 50%                              1.455201                            3.880451
# 75%                              1.517301                            4.491483
# max                              1.702423                            5.428250
#
#        emission_co2e_subsector_total_soil  emission_co2e_subsector_total_trns  \
# count                        28565.000000                        28565.000000
# mean                             1.062214                           42.999250
# std                              0.144147                            6.754547
# min                              0.551024                           14.161129
# 25%                              0.957412                           39.413899
# 50%                              1.063883                           45.130223
# 75%                              1.207439                           47.602613
# max                              1.249169                           67.525954
#
#        emission_co2e_subsector_total_trww  emission_co2e_subsector_total_waso
# count                        28565.000000                        28565.000000
# mean                             0.490128                            4.485322
# std                              0.060904                            1.245105
# min                              0.195593                            2.311322
# 25%                              0.461144                            3.453714
# 50%                              0.483947                            4.125385
# 75%                              0.515628                            5.194194
# max                              0.772694                            9.819255

# %%
# get the columns that have negative values
negative_cols = la_emissions_subsector_totals_df.columns[la_emissions_subsector_totals_df.min() < 0].to_list()
negative_cols
# Out:
# ['emission_co2e_subsector_total_ccsq', 'emission_co2e_subsector_total_frst']

# %%
# Get the columns that have positive values only
positive_cols = la_emissions_subsector_totals_df.columns[la_emissions_subsector_totals_df.min() >= 0].to_list()
positive_cols.remove("primary_id")
positive_cols.remove("time_period")
positive_cols
# Out:
# ['emission_co2e_subsector_total_agrc',
#  'emission_co2e_subsector_total_entc',
#  'emission_co2e_subsector_total_fgtv',
#  'emission_co2e_subsector_total_inen',
#  'emission_co2e_subsector_total_ippu',
#  'emission_co2e_subsector_total_lndu',
#  'emission_co2e_subsector_total_lsmm',
#  'emission_co2e_subsector_total_lvst',
#  'emission_co2e_subsector_total_scoe',
#  'emission_co2e_subsector_total_soil',
#  'emission_co2e_subsector_total_trns',
#  'emission_co2e_subsector_total_trww',
#  'emission_co2e_subsector_total_waso']

# %%
la_emissions_subsector_totals_df = la_emissions_subsector_totals_df.copy()
la_emissions_subsector_totals_df.loc["total_positive_emissions"] = la_emissions_subsector_totals_df[positive_cols].sum(axis=1)
la_emissions_subsector_totals_df.loc["total_negative_emissions"] = la_emissions_subsector_totals_df[negative_cols].sum(axis=1)

# %%
la_emissions_subsector_totals_df = la_emissions_subsector_totals_df[["primary_id", "time_period", "total_positive_emissions", "total_negative_emissions"]]
la_emissions_subsector_totals_df.head()
# Out:
#    primary_id  time_period  total_positive_emissions  total_negative_emissions
# 0    275275.0          7.0                224.420530                -36.545088
# 1    275275.0          8.0                219.190754                -38.817968
# 2    275275.0          9.0                230.061055                -40.622482
# 3    275275.0         10.0                229.855536                -42.118513
# 4    275275.0         11.0                229.677426                -43.406884

# %%
# Filter out rows with time_period <= 30
la_emissions_subsector_totals_df = la_emissions_subsector_totals_df[la_emissions_subsector_totals_df["time_period"] > 30]
la_emissions_subsector_totals_df.head(7)
# Out:
#     primary_id  time_period  total_positive_emissions  \
# 24    275275.0         31.0                 39.720313
# 25    275275.0         32.0                 36.577806
# 26    275275.0         33.0                 33.613109
# 27    275275.0         34.0                 30.761529
# 28    275275.0         35.0                 28.094935
# 53    275379.0         31.0                 86.467613
# 54    275379.0         32.0                 84.641241
#
#     total_negative_emissions
# 24                -68.138070
# 25                -69.801788
# 26                -71.516345
# 27                -73.272707
# 28                -75.057703
# 53                -49.034633
# 54                -49.280435

# %%
# aggregate data by primary_id and region by summing the emissions
la_emissions_df_agg = la_emissions_subsector_totals_df.groupby(["primary_id"]).sum().reset_index()
la_emissions_df_agg
# Out:
#      primary_id  time_period  total_positive_emissions  \
# 0      275275.0        165.0                168.767692
# 1      275276.0        165.0                590.733125
# 2      275277.0        165.0                482.293940
# 3      275278.0        165.0                308.455155
# 4      275279.0        165.0                543.963408
# ..          ...          ...                       ...
# 980    276271.0        165.0                461.336360
# 981    276272.0        165.0                648.527554
# 982    276273.0        165.0                568.344121
# 983    276274.0        165.0                619.478197
# 984    276275.0        165.0                600.362398
#
#      total_negative_emissions
# 0                 -357.786613
# 1                 -329.489684
# 2                 -232.721324
# 3                 -334.229504
# 4                 -314.565592
# ..                        ...
# 980               -367.300640
# 981               -421.423343
# 982               -317.572235
# 983               -292.876079
# 984               -357.003862
#
# [985 rows x 4 columns]

# %%
# Drop time period column as it is no longer needed
la_emissions_df_agg = la_emissions_df_agg.drop(columns=["time_period"], errors='ignore')
la_emissions_df_agg.describe()
# Out:
#           primary_id  total_positive_emissions  total_negative_emissions
# count     985.000000              9.850000e+02                985.000000
# mean   275776.930964              1.047788e+06               -327.438421
# std       289.326466              1.451735e+07                 48.313764
# min    275275.000000              1.687677e+02               -445.198593
# 25%    275528.000000              4.803161e+02               -362.724099
# 50%    275778.000000              5.430056e+02               -326.989494
# 75%    276027.000000              6.039230e+02               -292.290163
# max    276275.000000              3.037558e+08               -214.047846

# %% [markdown]
# ## Merge emissions data with lhs samples

# %%
attr_primary_df = pd.read_csv(os.path.join(SIMULATION_DIR_PATH, "ATTRIBUTE_PRIMARY.csv"))
attr_primary_df
# Out:
#       primary_id  design_id  strategy_id  future_id
# 0         275275          3         6002          0
# 1         275276          3         6002          1
# 2         275277          3         6002          2
# 3         275278          3         6002          3
# 4         275279          3         6002          4
# ...          ...        ...          ...        ...
# 996       276271          3         6002        996
# 997       276272          3         6002        997
# 998       276273          3         6002        998
# 999       276274          3         6002        999
# 1000      276275          3         6002       1000
#
# [1001 rows x 4 columns]

# %%
la_emissions_df_w_future_id = la_emissions_df_agg.merge(attr_primary_df, on="primary_id", how="inner")

# Drop design_id and stratgy_id columns
la_emissions_df_w_future_id = la_emissions_df_w_future_id.drop(columns=["design_id", "strategy_id"])
la_emissions_df_w_future_id
# Out:
#      primary_id  total_positive_emissions  total_negative_emissions  future_id
# 0      275275.0                168.767692               -357.786613          0
# 1      275276.0                590.733125               -329.489684          1
# 2      275277.0                482.293940               -232.721324          2
# 3      275278.0                308.455155               -334.229504          3
# 4      275279.0                543.963408               -314.565592          4
# ..          ...                       ...                       ...        ...
# 980    276271.0                461.336360               -367.300640        996
# 981    276272.0                648.527554               -421.423343        997
# 982    276273.0                568.344121               -317.572235        998
# 983    276274.0                619.478197               -292.876079        999
# 984    276275.0                600.362398               -357.003862       1000
#
# [985 rows x 4 columns]

# %%
merged_df = pd.merge(lhc_trials_df, la_emissions_df_w_future_id, on="future_id", how="inner")

# rearrange columns to have future_id and primary_id at the front
cols_order = ["future_id", "primary_id"] + [col for col in merged_df.columns if col not in ["future_id", "primary_id"]]
merged_df = merged_df[cols_order]
merged_df
# Out:
#      future_id  primary_id         1         2         3         4         5  \
# 0            1    275276.0  0.952436  0.360397  0.202990  0.995748  0.369859
# 1            2    275277.0  0.304955  0.204875  0.540658  0.800192  0.206396
# 2            3    275278.0  0.609262  0.366443  0.601808  0.916668  0.386475
# 3            4    275279.0  0.815313  0.487444  0.323954  0.634299  0.064625
# 4            5    275280.0  0.973878  0.842718  0.884382  0.483039  0.455502
# ..         ...         ...       ...       ...       ...       ...       ...
# 979        996    276271.0  0.218189  0.886941  0.569155  0.107766  0.955775
# 980        997    276272.0  0.510025  0.235856  0.847465  0.138888  0.182086
# 981        998    276273.0  0.276479  0.612911  0.642697  0.952037  0.176638
# 982        999    276274.0  0.600573  0.553323  0.306380  0.464389  0.834916
# 983       1000    276275.0  0.164542  0.057579  0.648085  0.210240  0.441924
#
#             6         7         8  ...      1473      1474      1475  \
# 0    0.919920  0.478450  0.445798  ...  0.482783  0.183188  0.364889
# 1    0.777352  0.805727  0.536048  ...  0.149747  0.308130  0.780839
# 2    0.181162  0.138910  0.768925  ...  0.348950  0.165501  0.813845
# 3    0.926815  0.633805  0.439346  ...  0.660562  0.621883  0.911838
# 4    0.003343  0.571994  0.108021  ...  0.621574  0.244454  0.927056
# ..        ...       ...       ...  ...       ...       ...       ...
# 979  0.380014  0.569711  0.312233  ...  0.883331  0.431040  0.045121
# 980  0.453749  0.242018  0.215693  ...  0.037013  0.528031  0.079728
# 981  0.411246  0.169671  0.694365  ...  0.657597  0.243538  0.603350
# 982  0.786519  0.717580  0.168263  ...  0.293393  0.632635  0.168413
# 983  0.364614  0.031031  0.873487  ...  0.115074  0.989445  0.965431
#
#          1476      1477      1478      1480      1481  \
# 0    0.005297  0.223598  0.927810  0.036368  0.933822
# 1    0.784662  0.742266  0.147130  0.081654  0.491202
# 2    0.950005  0.342632  0.053104  0.316417  0.173655
# 3    0.030974  0.912003  0.150989  0.246583  0.353195
# 4    0.561529  0.611280  0.552761  0.125694  0.147930
# ..        ...       ...       ...       ...       ...
# 979  0.790492  0.081530  0.351688  0.746613  0.853002
# 980  0.918024  0.653280  0.161674  0.033243  0.257661
# 981  0.377625  0.316224  0.615736  0.996441  0.704642
# 982  0.611178  0.295950  0.813797  0.934377  0.473035
# 983  0.352193  0.278569  0.164544  0.144563  0.306248
#
#      total_positive_emissions  total_negative_emissions
# 0                  590.733125               -329.489684
# 1                  482.293940               -232.721324
# 2                  308.455155               -334.229504
# 3                  543.963408               -314.565592
# 4                  485.590028               -360.621588
# ..                        ...                       ...
# 979                461.336360               -367.300640
# 980                648.527554               -421.423343
# 981                568.344121               -317.572235
# 982                619.478197               -292.876079
# 983                600.362398               -357.003862
#
# [984 rows x 88 columns]

# %%
var_traj_df = pd.read_csv(os.path.join(MAPPING_DIR_PATH, "var_trajgroups_experiment.csv"))
var_traj_df.tail(10)
# Out:
#     variable_trajectory_group
# 37                         38
# 38                         39
# 39                         40
# 40                         41
# 41                         42
# 42                         43
# 43                         44
# 44                         45
# 45                         46
# 46                         47

# %%
# Convert the variable_trajectory_group column to list of strings
relevant_lhs_cols = var_traj_df["variable_trajectory_group"].values
relevant_lhs_cols = [str(col) for col in relevant_lhs_cols.tolist()]
# relevant_lhs_cols

# %%
df_cols = merged_df.columns.tolist()

# Filter the relevant_lhs_cols to only include those that are in df_cols
relevant_lhs_cols = [col for col in relevant_lhs_cols if col in df_cols]

# %%
# filter merged_df to keep only relevant columns
cols_to_keep = ["future_id", "primary_id"] + list(relevant_lhs_cols) + ["total_positive_emissions", "total_negative_emissions"]
merged_df_filtered = merged_df[cols_to_keep]

# %%
merged_df_filtered
# Out:
#      future_id  primary_id         1         2         3         4         5  \
# 0            1    275276.0  0.952436  0.360397  0.202990  0.995748  0.369859
# 1            2    275277.0  0.304955  0.204875  0.540658  0.800192  0.206396
# 2            3    275278.0  0.609262  0.366443  0.601808  0.916668  0.386475
# 3            4    275279.0  0.815313  0.487444  0.323954  0.634299  0.064625
# 4            5    275280.0  0.973878  0.842718  0.884382  0.483039  0.455502
# ..         ...         ...       ...       ...       ...       ...       ...
# 979        996    276271.0  0.218189  0.886941  0.569155  0.107766  0.955775
# 980        997    276272.0  0.510025  0.235856  0.847465  0.138888  0.182086
# 981        998    276273.0  0.276479  0.612911  0.642697  0.952037  0.176638
# 982        999    276274.0  0.600573  0.553323  0.306380  0.464389  0.834916
# 983       1000    276275.0  0.164542  0.057579  0.648085  0.210240  0.441924
#
#             6         7         8  ...        40        41        42  \
# 0    0.919920  0.478450  0.445798  ...  0.289038  0.996557  0.053597
# 1    0.777352  0.805727  0.536048  ...  0.536533  0.385371  0.246165
# 2    0.181162  0.138910  0.768925  ...  0.533412  0.601590  0.122444
# 3    0.926815  0.633805  0.439346  ...  0.264120  0.938985  0.592915
# 4    0.003343  0.571994  0.108021  ...  0.430582  0.492564  0.432240
# ..        ...       ...       ...  ...       ...       ...       ...
# 979  0.380014  0.569711  0.312233  ...  0.004788  0.319760  0.567859
# 980  0.453749  0.242018  0.215693  ...  0.695228  0.368169  0.356410
# 981  0.411246  0.169671  0.694365  ...  0.326525  0.828078  0.653782
# 982  0.786519  0.717580  0.168263  ...  0.398381  0.757483  0.826523
# 983  0.364614  0.031031  0.873487  ...  0.389584  0.300123  0.936939
#
#            43        44        45        46        47  \
# 0    0.175103  0.379422  0.438093  0.149362  0.869757
# 1    0.101025  0.717013  0.368791  0.774941  0.483352
# 2    0.653845  0.216259  0.714853  0.881270  0.581230
# 3    0.564895  0.027725  0.138890  0.820709  0.250616
# 4    0.662820  0.179231  0.631375  0.395960  0.661637
# ..        ...       ...       ...       ...       ...
# 979  0.873065  0.309462  0.213959  0.531121  0.413153
# 980  0.584330  0.195851  0.217361  0.920388  0.402516
# 981  0.429175  0.977175  0.914779  0.307569  0.506892
# 982  0.961181  0.882943  0.900195  0.448056  0.664405
# 983  0.657785  0.017582  0.513939  0.232670  0.118241
#
#      total_positive_emissions  total_negative_emissions
# 0                  590.733125               -329.489684
# 1                  482.293940               -232.721324
# 2                  308.455155               -334.229504
# 3                  543.963408               -314.565592
# 4                  485.590028               -360.621588
# ..                        ...                       ...
# 979                461.336360               -367.300640
# 980                648.527554               -421.423343
# 981                568.344121               -317.572235
# 982                619.478197               -292.876079
# 983                600.362398               -357.003862
#
# [984 rows x 50 columns]

# %% [markdown]
# ## Add variable names to lhs columns

# %%
var_specifications_df = pd.read_csv(os.path.join(MAPPING_DIR_PATH, "variable_specification_to_sample_group.csv"))
# Filter var_specifications_df by sample_group in relevant_lhs_cols
relevant_lhs_cols = [int(col) for col in relevant_lhs_cols]
var_specifications_df = var_specifications_df[var_specifications_df["sample_group"].isin(relevant_lhs_cols)]
var_specifications_df = var_specifications_df.sort_values(by="sample_group", ascending=True)

# %%
def process_variable_prefix(df):
    result = []
    for group, group_df in df.groupby('sample_group'):
        variables = group_df['variable_specification'].tolist()
        if len(variables) == 1:
            prefix = variables[0]
        else:
            prefix = os.path.commonprefix(variables)
            # Clean trailing underscores
            prefix = prefix.rstrip('_')
            
        prefix = f"group_{group}_{prefix}"
        result.append({'sample_group': group, 'variable_prefix': prefix})
    return pd.DataFrame(result)

prefix_df = process_variable_prefix(var_specifications_df)
prefix_df
# Out:
#     sample_group                                    variable_prefix
# 0              1                            group_1_ef_lvst_entferm
# 1              2                                    group_2_yf_agrc
# 2              3                             group_3_demscalar_soil
# 3              4                             group_4_demscalar_ippu
# 4              5    group_5_efficfactor_enfu_industrial_energy_fuel
# 5              6                    group_6_elecfuelefficiency_trns
# 6              7   group_7_factor_waso_waste_per_capita_scalar_food
# 7              8                                  group_8_frac_fgtv
# 8              9      group_9_frac_agrc_agriculture_production_lost
# 9             10                                 group_10_frac_agrc
# 10            12  group_12_frac_enfu_transmission_loss_fuel_elec...
# 11            13                                          group_13_
# 12            14                  group_14_frac_ippu_cement_clinker
# 13            15     group_15_frac_ippu_production_with_co2_capture
# 14            16                              group_16_frac_lvst_mm
# 15            17                         group_17_frac_trns_fuelmix
# 16            18                group_18_frac_trns_mtkm_dem_freight
# 17            19                         group_19_frac_trns_pkm_dem
# 18            20                              group_20_frac_wali_ww
# 19            21                    group_21_frac_waso_non_recycled
# 20            22                                 group_22_frac_waso
# 21            23                        group_23_frac_waso_recycled
# 22            24                                 group_24_frac_waso
# 23            25                          group_25_frac_inen_energy
# 24            26                          group_26_frac_inen_energy
# 25            27                     group_27_frac_scoe_heat_energy
# 26            28                       group_28_fuelefficiency_trns
# 27            29                                     group_29_gasrf
# 28            30                             group_30_ef_ippu_tonne
# 29            31                     group_31_ef_ippu_tonne_n2o_per
# 30            32                  group_32_lndu_reallocation_factor
# 31            33                              group_33_exports_lvst
# 32            34                                group_34_nemomod_en
# 33            35  group_35_occrate_trns_passenger_per_vehicle_ro...
# 34            36                     group_36_pij_lndu_croplands_to
# 35            37             group_37_pij_lndu_forests_mangroves_to
# 36            38               group_38_pij_lndu_forests_primary_to
# 37            39             group_39_pij_lndu_forests_secondary_to
# 38            40                                          group_40_
# 39            41                         group_41_pij_lndu_other_to
# 40            42                   group_42_pij_lndu_settlements_to
# 41            43                      group_43_pij_lndu_wetlands_to
# 42            44       group_44_ef_agrc_anaerobicdom_rice_kg_ch4_ha
# 43            45             group_45_scalar_lvst_carrying_capacity
# 44            46       group_46_scalar_scoe_appliance_energy_demand
# 45            47            group_47_scalar_scoe_heat_energy_demand

# %%
var_specifications_df[var_specifications_df["sample_group"].isin([13, 40])]
# Out:
#                            variable_specification  sample_group
# 560   elasticity_agrc_sugar_cane_demand_to_income            13
# 876                     frac_gnrl_eating_red_meat            13
# 1177      frac_lndu_proportion_grasslands_pasture            40
# 2020       pij_lndu_grasslands_to_forests_primary            40
# 2021     pij_lndu_grasslands_to_forests_secondary            40
# 2022            pij_lndu_grasslands_to_grasslands            40
# 2024           pij_lndu_grasslands_to_settlements            40
# 2025              pij_lndu_grasslands_to_wetlands            40
# 2023                 pij_lndu_grasslands_to_other            40
# 2019     pij_lndu_grasslands_to_forests_mangroves            40
# 2018             pij_lndu_grasslands_to_croplands            40

# %%
prefix_df.loc[prefix_df["sample_group"] == 13, "variable_prefix"] = "group_13_frac_gnrl_eating_red_meats+"
prefix_df.loc[prefix_df["sample_group"] == 40, "variable_prefix"] = "group_40_pij_lndu_grasslands+"

prefix_df = prefix_df.sort_values(by="variable_prefix", ascending=True)
prefix_df
# Out:
#     sample_group                                    variable_prefix
# 9             10                                 group_10_frac_agrc
# 10            12  group_12_frac_enfu_transmission_loss_fuel_elec...
# 11            13               group_13_frac_gnrl_eating_red_meats+
# 12            14                  group_14_frac_ippu_cement_clinker
# 13            15     group_15_frac_ippu_production_with_co2_capture
# 14            16                              group_16_frac_lvst_mm
# 15            17                         group_17_frac_trns_fuelmix
# 16            18                group_18_frac_trns_mtkm_dem_freight
# 17            19                         group_19_frac_trns_pkm_dem
# 0              1                            group_1_ef_lvst_entferm
# 18            20                              group_20_frac_wali_ww
# 19            21                    group_21_frac_waso_non_recycled
# 20            22                                 group_22_frac_waso
# 21            23                        group_23_frac_waso_recycled
# 22            24                                 group_24_frac_waso
# 23            25                          group_25_frac_inen_energy
# 24            26                          group_26_frac_inen_energy
# 25            27                     group_27_frac_scoe_heat_energy
# 26            28                       group_28_fuelefficiency_trns
# 27            29                                     group_29_gasrf
# 1              2                                    group_2_yf_agrc
# 28            30                             group_30_ef_ippu_tonne
# 29            31                     group_31_ef_ippu_tonne_n2o_per
# 30            32                  group_32_lndu_reallocation_factor
# 31            33                              group_33_exports_lvst
# 32            34                                group_34_nemomod_en
# 33            35  group_35_occrate_trns_passenger_per_vehicle_ro...
# 34            36                     group_36_pij_lndu_croplands_to
# 35            37             group_37_pij_lndu_forests_mangroves_to
# 36            38               group_38_pij_lndu_forests_primary_to
# 37            39             group_39_pij_lndu_forests_secondary_to
# 2              3                             group_3_demscalar_soil
# 38            40                      group_40_pij_lndu_grasslands+
# 39            41                         group_41_pij_lndu_other_to
# 40            42                   group_42_pij_lndu_settlements_to
# 41            43                      group_43_pij_lndu_wetlands_to
# 42            44       group_44_ef_agrc_anaerobicdom_rice_kg_ch4_ha
# 43            45             group_45_scalar_lvst_carrying_capacity
# 44            46       group_46_scalar_scoe_appliance_energy_demand
# 45            47            group_47_scalar_scoe_heat_energy_demand
# 3              4                             group_4_demscalar_ippu
# 4              5    group_5_efficfactor_enfu_industrial_energy_fuel
# 5              6                    group_6_elecfuelefficiency_trns
# 6              7   group_7_factor_waso_waste_per_capita_scalar_food
# 7              8                                  group_8_frac_fgtv
# 8              9      group_9_frac_agrc_agriculture_production_lost

# %%
# Let's use the prefix_df to rename the columns in merged_df_filtered
def rename_columns_with_prefix(merged_df, prefix_df):
    df = merged_df.copy()
    for _, row in prefix_df.iterrows():
        sample_group = row['sample_group']
        variable_prefix = row['variable_prefix']
        cols_to_rename = [col for col in df.columns if col.startswith(str(sample_group))]
        for col in cols_to_rename:
            new_col_name = f"{variable_prefix}"
            df = df.rename(columns={col: new_col_name})
    return df
merged_df_filtered_w_prefix = rename_columns_with_prefix(merged_df_filtered, prefix_df)

# %%
merged_df_filtered_w_prefix
# Out:
#      future_id  primary_id  group_1_ef_lvst_entferm  group_2_yf_agrc  \
# 0            1    275276.0                 0.952436         0.360397
# 1            2    275277.0                 0.304955         0.204875
# 2            3    275278.0                 0.609262         0.366443
# 3            4    275279.0                 0.815313         0.487444
# 4            5    275280.0                 0.973878         0.842718
# ..         ...         ...                      ...              ...
# 979        996    276271.0                 0.218189         0.886941
# 980        997    276272.0                 0.510025         0.235856
# 981        998    276273.0                 0.276479         0.612911
# 982        999    276274.0                 0.600573         0.553323
# 983       1000    276275.0                 0.164542         0.057579
#
#      group_3_demscalar_soil  group_4_demscalar_ippu  \
# 0                  0.202990                0.995748
# 1                  0.540658                0.800192
# 2                  0.601808                0.916668
# 3                  0.323954                0.634299
# 4                  0.884382                0.483039
# ..                      ...                     ...
# 979                0.569155                0.107766
# 980                0.847465                0.138888
# 981                0.642697                0.952037
# 982                0.306380                0.464389
# 983                0.648085                0.210240
#
#      group_5_efficfactor_enfu_industrial_energy_fuel  \
# 0                                           0.369859
# 1                                           0.206396
# 2                                           0.386475
# 3                                           0.064625
# 4                                           0.455502
# ..                                               ...
# 979                                         0.955775
# 980                                         0.182086
# 981                                         0.176638
# 982                                         0.834916
# 983                                         0.441924
#
#      group_6_elecfuelefficiency_trns  \
# 0                           0.919920
# 1                           0.777352
# 2                           0.181162
# 3                           0.926815
# 4                           0.003343
# ..                               ...
# 979                         0.380014
# 980                         0.453749
# 981                         0.411246
# 982                         0.786519
# 983                         0.364614
#
#      group_7_factor_waso_waste_per_capita_scalar_food  group_8_frac_fgtv  ...  \
# 0                                            0.478450           0.445798  ...
# 1                                            0.805727           0.536048  ...
# 2                                            0.138910           0.768925  ...
# 3                                            0.633805           0.439346  ...
# 4                                            0.571994           0.108021  ...
# ..                                                ...                ...  ...
# 979                                          0.569711           0.312233  ...
# 980                                          0.242018           0.215693  ...
# 981                                          0.169671           0.694365  ...
# 982                                          0.717580           0.168263  ...
# 983                                          0.031031           0.873487  ...
#
#      group_40_pij_lndu_grasslands+  group_41_pij_lndu_other_to  \
# 0                         0.289038                    0.996557
# 1                         0.536533                    0.385371
# 2                         0.533412                    0.601590
# 3                         0.264120                    0.938985
# 4                         0.430582                    0.492564
# ..                             ...                         ...
# 979                       0.004788                    0.319760
# 980                       0.695228                    0.368169
# 981                       0.326525                    0.828078
# 982                       0.398381                    0.757483
# 983                       0.389584                    0.300123
#
#      group_42_pij_lndu_settlements_to  group_43_pij_lndu_wetlands_to  \
# 0                            0.053597                       0.175103
# 1                            0.246165                       0.101025
# 2                            0.122444                       0.653845
# 3                            0.592915                       0.564895
# 4                            0.432240                       0.662820
# ..                                ...                            ...
# 979                          0.567859                       0.873065
# 980                          0.356410                       0.584330
# 981                          0.653782                       0.429175
# 982                          0.826523                       0.961181
# 983                          0.936939                       0.657785
#
#      group_44_ef_agrc_anaerobicdom_rice_kg_ch4_ha  \
# 0                                        0.379422
# 1                                        0.717013
# 2                                        0.216259
# 3                                        0.027725
# 4                                        0.179231
# ..                                            ...
# 979                                      0.309462
# 980                                      0.195851
# 981                                      0.977175
# 982                                      0.882943
# 983                                      0.017582
#
#      group_45_scalar_lvst_carrying_capacity  \
# 0                                  0.438093
# 1                                  0.368791
# 2                                  0.714853
# 3                                  0.138890
# 4                                  0.631375
# ..                                      ...
# 979                                0.213959
# 980                                0.217361
# 981                                0.914779
# 982                                0.900195
# 983                                0.513939
#
#      group_46_scalar_scoe_appliance_energy_demand  \
# 0                                        0.149362
# 1                                        0.774941
# 2                                        0.881270
# 3                                        0.820709
# 4                                        0.395960
# ..                                            ...
# 979                                      0.531121
# 980                                      0.920388
# 981                                      0.307569
# 982                                      0.448056
# 983                                      0.232670
#
#      group_47_scalar_scoe_heat_energy_demand  total_positive_emissions  \
# 0                                   0.869757                590.733125
# 1                                   0.483352                482.293940
# 2                                   0.581230                308.455155
# 3                                   0.250616                543.963408
# 4                                   0.661637                485.590028
# ..                                       ...                       ...
# 979                                 0.413153                461.336360
# 980                                 0.402516                648.527554
# 981                                 0.506892                568.344121
# 982                                 0.664405                619.478197
# 983                                 0.118241                600.362398
#
#      total_negative_emissions
# 0                 -329.489684
# 1                 -232.721324
# 2                 -334.229504
# 3                 -314.565592
# 4                 -360.621588
# ..                        ...
# 979               -367.300640
# 980               -421.423343
# 981               -317.572235
# 982               -292.876079
# 983               -357.003862
#
# [984 rows x 50 columns]

# %%
#save the merged DataFrame to a CSV file
merged_df_filtered_w_prefix.to_csv(os.path.join(TRAINING_DIR_PATH, "training_data_v2.csv"), index=False)
