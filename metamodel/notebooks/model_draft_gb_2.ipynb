# %%
import pandas as pd
import os
from utils.ml_utils import PreprocessingUtils, GBEmissionsPredictionPipeline
from utils.eda_utils import EDAUtils, DataCleaningUtils
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
SCRIPT_DIR_PATH = os.getcwd()
ROOT_DIR_PATH = os.path.dirname(SCRIPT_DIR_PATH)
DATA_DIR_PATH = os.path.join(ROOT_DIR_PATH, "data")
MAPPING_DIR_PATH = os.path.join(DATA_DIR_PATH, "mapping")
PREDICTORS_DIR_PATH = os.path.join(DATA_DIR_PATH, "predictors")
SSP_DIR_PATH = os.path.join(DATA_DIR_PATH, "ssp")
SIMULATION_DIR_PATH = os.path.join(SSP_DIR_PATH, "sisepuede_run_2025-01-14T17;04;06.975301_output_database")
TRAINING_DIR_PATH = os.path.join(DATA_DIR_PATH, "training")

# %%
TRAINING_DATA_PATH = os.path.join(TRAINING_DIR_PATH, "training_data.csv")
training_df = pd.read_csv(TRAINING_DATA_PATH)
training_df = training_df.drop(columns=["primary_id", "future_id"])
training_df.head()
# Out:
#    group_1_ef_lvst_entferm  group_2_yf_agrc  group_3_demscalar_soil  \
# 0                 0.952436         0.360397                0.202990
# 1                 0.304955         0.204875                0.540658
# 2                 0.609262         0.366443                0.601808
# 3                 0.815313         0.487444                0.323954
# 4                 0.973878         0.842718                0.884382
#
#    group_4_demscalar_ippu  group_5_efficfactor_enfu_industrial_energy_fuel  \
# 0                0.995748                                         0.369859
# 1                0.800192                                         0.206396
# 2                0.916668                                         0.386475
# 3                0.634299                                         0.064625
# 4                0.483039                                         0.455502
#
#    group_6_elecfuelefficiency_trns  \
# 0                         0.919920
# 1                         0.777352
# 2                         0.181162
# 3                         0.926815
# 4                         0.003343
#
#    group_7_factor_waso_waste_per_capita_scalar_food  group_8_frac_fgtv  \
# 0                                          0.478450           0.445798
# 1                                          0.805727           0.536048
# 2                                          0.138910           0.768925
# 3                                          0.633805           0.439346
# 4                                          0.571994           0.108021
#
#    group_9_frac_agrc_agriculture_production_lost  group_10_frac_agrc  ...  \
# 0                                       0.490988            0.510280  ...
# 1                                       0.779857            0.623335  ...
# 2                                       0.884425            0.232722  ...
# 3                                       0.027114            0.532020  ...
# 4                                       0.346714            0.892123  ...
#
#    emission_co2e_subsector_total_last_five_years_inen  \
# 0                                          32.437006
# 1                                          37.959592
# 2                                          19.116132
# 3                                          48.859457
# 4                                          27.739520
#
#    emission_co2e_subsector_total_last_five_years_ippu  \
# 0                                         170.411122
# 1                                         160.811434
# 2                                         278.256437
# 3                                         336.430495
# 4                                         251.830128
#
#    emission_co2e_subsector_total_last_five_years_lndu  \
# 0                                          49.462783
# 1                                          38.170739
# 2                                          36.429337
# 3                                          28.664949
# 4                                          46.485526
#
#    emission_co2e_subsector_total_last_five_years_lsmm  \
# 0                                           0.906453
# 1                                           0.970521
# 2                                           1.228347
# 3                                           1.090020
# 4                                           0.984459
#
#    emission_co2e_subsector_total_last_five_years_lvst  \
# 0                                           3.535574
# 1                                           4.244111
# 2                                           4.422138
# 3                                           3.910358
# 4                                           3.737274
#
#    emission_co2e_subsector_total_last_five_years_scoe  \
# 0                                           8.152285
# 1                                           8.154926
# 2                                          18.414907
# 3                                          13.270447
# 4                                          15.296131
#
#    emission_co2e_subsector_total_last_five_years_soil  \
# 0                                          89.352384
# 1                                          81.322226
# 2                                          76.882749
# 3                                          70.415909
# 4                                          76.307252
#
#    emission_co2e_subsector_total_last_five_years_trns  \
# 0                                         138.564932
# 1                                         156.911769
# 2                                         121.007564
# 3                                         121.967384
# 4                                         229.067385
#
#    emission_co2e_subsector_total_last_five_years_trww  \
# 0                                           4.811716
# 1                                           8.015643
# 2                                           4.921821
# 3                                           6.411074
# 4                                           7.548845
#
#    emission_co2e_subsector_total_last_five_years_waso
# 0                                          12.035590
# 1                                           5.746137
# 2                                           5.133122
# 3                                           8.231365
# 4                                          10.952978
#
# [5 rows x 62 columns]

# %%
# Set some parameters
use_pca = False

# %% [markdown]
# ## EDA

# %%
edau = EDAUtils()

# %%
emission_subsector_cols = [col for col in training_df.columns if col.startswith("emission_co2e")]
emission_subsector_cols
# Out:
# ['emission_co2e_subsector_total_last_five_years_agrc',
#  'emission_co2e_subsector_total_last_five_years_ccsq',
#  'emission_co2e_subsector_total_last_five_years_entc',
#  'emission_co2e_subsector_total_last_five_years_fgtv',
#  'emission_co2e_subsector_total_last_five_years_frst',
#  'emission_co2e_subsector_total_last_five_years_inen',
#  'emission_co2e_subsector_total_last_five_years_ippu',
#  'emission_co2e_subsector_total_last_five_years_lndu',
#  'emission_co2e_subsector_total_last_five_years_lsmm',
#  'emission_co2e_subsector_total_last_five_years_lvst',
#  'emission_co2e_subsector_total_last_five_years_scoe',
#  'emission_co2e_subsector_total_last_five_years_soil',
#  'emission_co2e_subsector_total_last_five_years_trns',
#  'emission_co2e_subsector_total_last_five_years_trww',
#  'emission_co2e_subsector_total_last_five_years_waso']

# %%
lhs_group_cols = [col for col in training_df.columns if col.startswith("group_")]
# lhs_group_cols

# %%
training_df[emission_subsector_cols].describe()
# Out:
#        emission_co2e_subsector_total_last_five_years_agrc  \
# count                                        1000.000000
# mean                                            7.535185
# std                                             0.930252
# min                                             5.120382
# 25%                                             6.874223
# 50%                                             7.509914
# 75%                                             8.170789
# max                                             9.807744
#
#        emission_co2e_subsector_total_last_five_years_ccsq  \
# count                                        1000.000000
# mean                                          -78.060794
# std                                            36.893240
# min                                          -141.860906
# 25%                                          -109.919278
# 50%                                           -78.115395
# 75%                                           -46.128974
# max                                           -14.219294
#
#        emission_co2e_subsector_total_last_five_years_entc  \
# count                                        1000.000000
# mean                                          199.761485
# std                                            66.674477
# min                                             0.000000
# 25%                                           149.967427
# 50%                                           189.615348
# 75%                                           246.149940
# max                                           406.028208
#
#        emission_co2e_subsector_total_last_five_years_fgtv  \
# count                                       1.000000e+03
# mean                                        7.684060e+05
# std                                         1.071674e+07
# min                                         0.000000e+00
# 25%                                         1.794705e+01
# 50%                                         2.445040e+01
# 75%                                         3.490386e+01
# max                                         2.268710e+08
#
#        emission_co2e_subsector_total_last_five_years_frst  \
# count                                        1000.000000
# mean                                         -120.624093
# std                                            16.057323
# min                                          -152.511771
# 25%                                          -133.930444
# 50%                                          -120.804051
# 75%                                          -107.020154
# max                                           -88.566561
#
#        emission_co2e_subsector_total_last_five_years_inen  \
# count                                        1000.000000
# mean                                           37.985035
# std                                            13.088637
# min                                             9.481405
# 25%                                            27.532930
# 50%                                            37.731565
# 75%                                            47.709225
# max                                            74.039201
#
#        emission_co2e_subsector_total_last_five_years_ippu  \
# count                                        1000.000000
# mean                                          288.384484
# std                                            70.745006
# min                                           130.962794
# 25%                                           233.362873
# 50%                                           284.777596
# 75%                                           338.326399
# max                                           485.800910
#
#        emission_co2e_subsector_total_last_five_years_lndu  \
# count                                        1000.000000
# mean                                           42.142291
# std                                             7.398531
# min                                            27.019688
# 25%                                            35.965916
# 50%                                            42.640595
# 75%                                            48.297592
# max                                            57.797043
#
#        emission_co2e_subsector_total_last_five_years_lsmm  \
# count                                        1000.000000
# mean                                            1.081823
# std                                             0.195306
# min                                             0.628799
# 25%                                             0.939363
# 50%                                             1.074327
# 75%                                             1.221827
# max                                             1.583632
#
#        emission_co2e_subsector_total_last_five_years_lvst  \
# count                                        1000.000000
# mean                                            4.692572
# std                                             0.698426
# min                                             3.033455
# 25%                                             4.188121
# 50%                                             4.652400
# 75%                                             5.197214
# max                                             6.614399
#
#        emission_co2e_subsector_total_last_five_years_scoe  \
# count                                        1000.000000
# mean                                           13.311118
# std                                             6.761102
# min                                             1.936001
# 25%                                             7.524093
# 50%                                            13.052387
# 75%                                            18.305368
# max                                            30.221088
#
#        emission_co2e_subsector_total_last_five_years_soil  \
# count                                        1000.000000
# mean                                           76.799055
# std                                             7.574320
# min                                            52.805124
# 25%                                            71.486278
# 50%                                            76.361649
# 75%                                            82.129659
# max                                            98.078386
#
#        emission_co2e_subsector_total_last_five_years_trns  \
# count                                        1000.000000
# mean                                          200.596342
# std                                            51.888531
# min                                            98.222119
# 25%                                           156.277242
# 50%                                           199.285265
# 75%                                           242.048252
# max                                           340.471613
#
#        emission_co2e_subsector_total_last_five_years_trww  \
# count                                        1000.000000
# mean                                            7.082923
# std                                             1.633506
# min                                             3.750551
# 25%                                             5.736882
# 50%                                             7.058855
# 75%                                             8.447790
# max                                            10.683759
#
#        emission_co2e_subsector_total_last_five_years_waso
# count                                        1000.000000
# mean                                            9.340795
# std                                             3.001107
# min                                             3.835560
# 25%                                             6.751803
# 50%                                             9.373437
# 75%                                            11.946039
# max                                            14.956282

# %%
edau.plot_multiple_histograms(training_df, emission_subsector_cols, title="Distribution of Emission Subsector Columns")

# %%
# Correlation with target variable
for col in emission_subsector_cols:
    print(edau.get_target_var_corr(training_df[lhs_group_cols + [col]], col))
# Out:
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_agrc' (threshold: 0.1):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_agrc : 1.0000
# group_44_ef_agrc_anaerobicdom_rice_kg_ch4_ha : 0.7417
# group_10_frac_agrc             : 0.4771
# group_32_lndu_reallocation_factor : 0.3992
# group_2_yf_agrc                : 0.1580
# group_13_frac_gnrl_eating_red_meats+ : 0.1490
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_ccsq' (threshold: 0.1):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_ccsq : 1.0000
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_entc' (threshold: 0.1):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_entc : 1.0000
# group_34_nemomod_en            : 0.8704
# group_26_frac_inen_energy      : 0.1833
# group_17_frac_trns_fuelmix     : 0.1244
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_fgtv' (threshold: 0.1):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_fgtv : 1.0000
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_frst' (threshold: 0.1):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_frst : 1.0000
# group_4_demscalar_ippu         : 0.9878
# group_37_pij_lndu_forests_mangroves_to : 0.1540
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_inen' (threshold: 0.1):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_inen : 1.0000
# group_26_frac_inen_energy      : 0.8643
# group_25_frac_inen_energy      : 0.2211
# group_4_demscalar_ippu         : 0.2140
# group_5_efficfactor_enfu_industrial_energy_fuel : 0.1917
# group_15_frac_ippu_production_with_co2_capture : 0.1894
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_ippu' (threshold: 0.1):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_ippu : 1.0000
# group_31_ef_ippu_tonne_n2o_per : 0.8502
# group_15_frac_ippu_production_with_co2_capture : 0.3771
# group_4_demscalar_ippu         : 0.2855
# group_30_ef_ippu_tonne         : 0.1077
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_lndu' (threshold: 0.1):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_lndu : 1.0000
# group_37_pij_lndu_forests_mangroves_to : 0.9717
# group_39_pij_lndu_forests_secondary_to : 0.1024
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_lsmm' (threshold: 0.1):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_lsmm : 1.0000
# group_16_frac_lvst_mm          : 0.7852
# group_13_frac_gnrl_eating_red_meats+ : 0.5234
# group_45_scalar_lvst_carrying_capacity : 0.1610
# group_29_gasrf                 : 0.1572
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_lvst' (threshold: 0.1):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_lvst : 1.0000
# group_1_ef_lvst_entferm        : 0.7913
# group_45_scalar_lvst_carrying_capacity : 0.3887
# group_13_frac_gnrl_eating_red_meats+ : 0.3647
# group_32_lndu_reallocation_factor : 0.1255
# group_2_yf_agrc                : 0.1180
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_scoe' (threshold: 0.1):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_scoe : 1.0000
# group_27_frac_scoe_heat_energy : 0.9389
# group_47_scalar_scoe_heat_energy_demand : 0.3175
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_soil' (threshold: 0.1):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_soil : 1.0000
# group_37_pij_lndu_forests_mangroves_to : 0.6192
# group_3_demscalar_soil         : 0.5377
# group_32_lndu_reallocation_factor : 0.4054
# group_2_yf_agrc                : 0.3070
# group_13_frac_gnrl_eating_red_meats+ : 0.1386
# group_9_frac_agrc_agriculture_production_lost : 0.1233
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_trns' (threshold: 0.1):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_trns : 1.0000
# group_17_frac_trns_fuelmix     : 0.9395
# group_28_fuelefficiency_trns   : 0.2280
# group_19_frac_trns_pkm_dem     : 0.1287
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_trww' (threshold: 0.1):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_trww : 1.0000
# group_29_gasrf                 : 0.9775
# group_13_frac_gnrl_eating_red_meats+ : 0.1554
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_waso' (threshold: 0.1):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_waso : 1.0000
# group_24_frac_waso             : 0.9961
# ==================================================
#
# None

# %%
# # Summary table
# summary = edau.numeric_summary(training_df)
# summary

# %%
# Find constant / near-constant cols
const_cols = edau.find_constant_columns(training_df)
near_const_cols = edau.find_near_constant_columns(training_df, threshold=1e-2)
print("Constant:", const_cols)
print("Near-constant:", near_const_cols)
# Out:
# Constant: []
# Near-constant: []

# %%
# Outlier inspection
outliers = edau.find_outlier_columns(training_df, z_thresh=3.0)
print("Outlier percentages:", outliers)
# Out:
# Outlier percentages: {'total_emissions_last_five_years': 0.6, 'emission_co2e_subsector_total_last_five_years_entc': 0.2, 'emission_co2e_subsector_total_last_five_years_fgtv': 0.6, 'emission_co2e_subsector_total_last_five_years_soil': 0.1}

# %%
# Plot all histograms (will show a big grid of 80 plots)
# edau.plot_all_histograms(training_df, bins=30, max_cols=5, figsize_per_plot=(3,2))

# %% [markdown]
# ## Data Cleaning

# %%
dcu = DataCleaningUtils()

# %%
training_df.shape
# Out:
# (1000, 62)

# %%
training_df_cleaned = dcu.remove_outliers(training_df)
print("Shape after removing outliers:", training_df_cleaned.shape)
# Out:
# Shape after removing outliers: (991, 62)

# %%
edau.plot_multiple_histograms(training_df_cleaned, emission_subsector_cols, title="Distribution of Emission Subsector Columns")

# %%
outliers = edau.find_outlier_columns(training_df_cleaned, z_thresh=3.0)
print("Outlier percentages:", outliers)
# Out:
# Outlier percentages: {'total_emissions_last_five_years': 0.10090817356205853, 'emission_co2e_subsector_total_last_five_years_entc': 1.513622603430878, 'emission_co2e_subsector_total_last_five_years_fgtv': 0.30272452068617556}

# %%
# Get the corr with target variable again
for col in emission_subsector_cols:
    print(edau.get_target_var_corr(training_df_cleaned[lhs_group_cols + [col]], col, threshold=0.2))
# Out:
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_agrc' (threshold: 0.2):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_agrc : 1.0000
# group_44_ef_agrc_anaerobicdom_rice_kg_ch4_ha : 0.7416
# group_10_frac_agrc             : 0.4757
# group_32_lndu_reallocation_factor : 0.3957
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_ccsq' (threshold: 0.2):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_ccsq : 1.0000
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_entc' (threshold: 0.2):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_entc : 1.0000
# group_34_nemomod_en            : 0.8710
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_fgtv' (threshold: 0.2):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_fgtv : 1.0000
# group_34_nemomod_en            : 0.7167
# group_8_frac_fgtv              : 0.5872
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_frst' (threshold: 0.2):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_frst : 1.0000
# group_4_demscalar_ippu         : 0.9879
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_inen' (threshold: 0.2):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_inen : 1.0000
# group_26_frac_inen_energy      : 0.8645
# group_25_frac_inen_energy      : 0.2183
# group_4_demscalar_ippu         : 0.2159
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_ippu' (threshold: 0.2):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_ippu : 1.0000
# group_31_ef_ippu_tonne_n2o_per : 0.8503
# group_15_frac_ippu_production_with_co2_capture : 0.3738
# group_4_demscalar_ippu         : 0.2837
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_lndu' (threshold: 0.2):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_lndu : 1.0000
# group_37_pij_lndu_forests_mangroves_to : 0.9716
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_lsmm' (threshold: 0.2):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_lsmm : 1.0000
# group_16_frac_lvst_mm          : 0.7845
# group_13_frac_gnrl_eating_red_meats+ : 0.5212
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_lvst' (threshold: 0.2):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_lvst : 1.0000
# group_1_ef_lvst_entferm        : 0.7915
# group_45_scalar_lvst_carrying_capacity : 0.3883
# group_13_frac_gnrl_eating_red_meats+ : 0.3658
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_scoe' (threshold: 0.2):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_scoe : 1.0000
# group_27_frac_scoe_heat_energy : 0.9389
# group_47_scalar_scoe_heat_energy_demand : 0.3217
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_soil' (threshold: 0.2):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_soil : 1.0000
# group_37_pij_lndu_forests_mangroves_to : 0.6162
# group_3_demscalar_soil         : 0.5367
# group_32_lndu_reallocation_factor : 0.3995
# group_2_yf_agrc                : 0.3010
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_trns' (threshold: 0.2):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_trns : 1.0000
# group_17_frac_trns_fuelmix     : 0.9396
# group_28_fuelefficiency_trns   : 0.2273
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_trww' (threshold: 0.2):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_trww : 1.0000
# group_29_gasrf                 : 0.9775
# ==================================================
#
# None
#
# ==================================================
# Correlation with target variable 'emission_co2e_subsector_total_last_five_years_waso' (threshold: 0.2):
# --------------------------------------------------
# emission_co2e_subsector_total_last_five_years_waso : 1.0000
# group_24_frac_waso             : 0.9961
# ==================================================
#
# None

# %%
# edau.check_for_multicollinearity(training_df_cleaned, threshold=0.8)

# %% [markdown]
# ## Preprocessing

# %%
ppu = PreprocessingUtils()

# %% [markdown]
# ## ML

# %%
for subsector in emission_subsector_cols:
    epp = GBEmissionsPredictionPipeline(training_df_cleaned[lhs_group_cols + [subsector]], target=subsector, test_size=0.2, random_state=42)
    print(f"Running pipeline for subsector: {subsector}")
    # print(f"Columns used: {epp.df.columns.tolist()}")
    epp.run(tune=False, log_transform=False, create_plots=False)
# Out:
# Running pipeline for subsector: emission_co2e_subsector_total_last_five_years_agrc
# MAE:  0.1476
# RMSE: 0.1812
# R²:   0.9645
#
# Cross-Validation Results:
# test_MAE: Mean=0.1797, Std=0.0186
# test_R2: Mean=0.9404, Std=0.0106
# test_RMSE: Mean=0.2226, Std=0.0215
# Running pipeline for subsector: emission_co2e_subsector_total_last_five_years_ccsq
# MAE:  33.4167
# RMSE: 39.5670
# R²:   -0.1874
#
# Cross-Validation Results:
# test_MAE: Mean=33.3386, Std=0.8030
# test_R2: Mean=-0.1459, Std=0.0601
# test_RMSE: Mean=39.4136, Std=0.9947
# Running pipeline for subsector: emission_co2e_subsector_total_last_five_years_entc
# MAE:  14.4322
# RMSE: 26.0450
# R²:   0.8220
#
# Cross-Validation Results:
# test_MAE: Mean=16.6130, Std=1.1808
# test_R2: Mean=0.8022, Std=0.0256
# test_RMSE: Mean=29.7517, Std=2.1004
# Running pipeline for subsector: emission_co2e_subsector_total_last_five_years_fgtv
# MAE:  2.4278
# RMSE: 3.8112
# R²:   0.8841
#
# Cross-Validation Results:
# test_MAE: Mean=2.9592, Std=0.1631
# test_R2: Mean=0.8693, Std=0.0126
# test_RMSE: Mean=4.5040, Std=0.2394
# Running pipeline for subsector: emission_co2e_subsector_total_last_five_years_frst
# MAE:  0.8030
# RMSE: 1.0201
# R²:   0.9958
#
# Cross-Validation Results:
# test_MAE: Mean=0.8544, Std=0.0260
# test_R2: Mean=0.9952, Std=0.0005
# test_RMSE: Mean=1.1135, Std=0.0436
# Running pipeline for subsector: emission_co2e_subsector_total_last_five_years_inen
# MAE:  2.4820
# RMSE: 3.2118
# R²:   0.9426
#
# Cross-Validation Results:
# test_MAE: Mean=2.7834, Std=0.0686
# test_R2: Mean=0.9236, Std=0.0069
# test_RMSE: Mean=3.5625, Std=0.1553
# Running pipeline for subsector: emission_co2e_subsector_total_last_five_years_ippu
# MAE:  8.0684
# RMSE: 10.2330
# R²:   0.9804
#
# Cross-Validation Results:
# test_MAE: Mean=9.2465, Std=0.7592
# test_R2: Mean=0.9711, Std=0.0059
# test_RMSE: Mean=11.8229, Std=1.1696
# Running pipeline for subsector: emission_co2e_subsector_total_last_five_years_lndu
# MAE:  0.8712
# RMSE: 1.1240
# R²:   0.9755
#
# Cross-Validation Results:
# test_MAE: Mean=0.8983, Std=0.0517
# test_R2: Mean=0.9716, Std=0.0052
# test_RMSE: Mean=1.2433, Std=0.1107
# Running pipeline for subsector: emission_co2e_subsector_total_last_five_years_lsmm
# MAE:  0.0243
# RMSE: 0.0305
# R²:   0.9752
#
# Cross-Validation Results:
# test_MAE: Mean=0.0317, Std=0.0014
# test_R2: Mean=0.9574, Std=0.0062
# test_RMSE: Mean=0.0398, Std=0.0024
# Running pipeline for subsector: emission_co2e_subsector_total_last_five_years_lvst
# MAE:  0.1047
# RMSE: 0.1345
# R²:   0.9537
#
# Cross-Validation Results:
# test_MAE: Mean=0.1317, Std=0.0131
# test_R2: Mean=0.9448, Std=0.0066
# test_RMSE: Mean=0.1673, Std=0.0169
# Running pipeline for subsector: emission_co2e_subsector_total_last_five_years_scoe
# MAE:  0.2123
# RMSE: 0.2804
# R²:   0.9983
#
# Cross-Validation Results:
# test_MAE: Mean=0.2730, Std=0.0121
# test_R2: Mean=0.9971, Std=0.0005
# test_RMSE: Mean=0.3582, Std=0.0248
# Running pipeline for subsector: emission_co2e_subsector_total_last_five_years_soil
# MAE:  1.4956
# RMSE: 1.8309
# R²:   0.9409
#
# Cross-Validation Results:
# test_MAE: Mean=1.7374, Std=0.1594
# test_R2: Mean=0.9172, Std=0.0143
# test_RMSE: Mean=2.1531, Std=0.2047
# Running pipeline for subsector: emission_co2e_subsector_total_last_five_years_trns
# MAE:  10.0030
# RMSE: 12.1855
# R²:   0.9305
#
# Cross-Validation Results:
# test_MAE: Mean=11.9213, Std=0.8786
# test_R2: Mean=0.9215, Std=0.0121
# test_RMSE: Mean=14.8015, Std=1.1255
# Running pipeline for subsector: emission_co2e_subsector_total_last_five_years_trww
# MAE:  0.0789
# RMSE: 0.1034
# R²:   0.9953
#
# Cross-Validation Results:
# test_MAE: Mean=0.0907, Std=0.0041
# test_R2: Mean=0.9949, Std=0.0005
# test_RMSE: Mean=0.1184, Std=0.0062
# Running pipeline for subsector: emission_co2e_subsector_total_last_five_years_waso
# MAE:  0.0787
# RMSE: 0.1014
# R²:   0.9990
#
# Cross-Validation Results:
# test_MAE: Mean=0.0930, Std=0.0044
# test_R2: Mean=0.9983, Std=0.0002
# test_RMSE: Mean=0.1201, Std=0.0068
