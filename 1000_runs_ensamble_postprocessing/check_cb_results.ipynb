# %%
import pandas as pd
import os

# %%
# Set up paths
SCRIPT_DIR_PATH = os.getcwd()
CW_DIR_PATH = os.path.join(SCRIPT_DIR_PATH, "cw")
DATA_DIR_PATH = os.path.join(SCRIPT_DIR_PATH, "data")
OUTPUT_DIR_PATH = os.path.join(SCRIPT_DIR_PATH, "output")

# %%
# cb_df = pd.read_csv(os.path.join(OUTPUT_DIR_PATH, "combined_cb_results_de38bb46-7d00-4cf5-8844-f6cc20695024.csv"))
cb_df = pd.read_csv(os.path.join(OUTPUT_DIR_PATH, "cb_la.csv"))
cb_df.head()
# Out:
#          strategy_code  future_id     region  time_period  \
# 0  PFLO:ALL_LA_ACTIONS        648  louisiana          7.0
# 1  PFLO:ALL_LA_ACTIONS        648  louisiana          8.0
# 2  PFLO:ALL_LA_ACTIONS        648  louisiana          9.0
# 3  PFLO:ALL_LA_ACTIONS        648  louisiana         10.0
# 4  PFLO:ALL_LA_ACTIONS        648  louisiana         11.0
#
#     difference_variable  variable_value_baseline  variable_value_pathway  \
# 0  pop_unimproved_rural            299091.209054           299091.209054
# 1  pop_unimproved_rural            294340.078493           294340.078493
# 2  pop_unimproved_rural            289474.711388           289474.711388
# 3  pop_unimproved_rural            284494.629299           284494.629299
# 4  pop_unimproved_rural            279403.968085           279403.968085
#
#    difference_value                                       variable  value  \
# 0               0.0  cb:wali:technical_cost:sanitation:unimp_rural    0.0
# 1               0.0  cb:wali:technical_cost:sanitation:unimp_rural    0.0
# 2               0.0  cb:wali:technical_cost:sanitation:unimp_rural    0.0
# 3               0.0  cb:wali:technical_cost:sanitation:unimp_rural   -0.0
# 4               0.0  cb:wali:technical_cost:sanitation:unimp_rural   -0.0
#
#    primary_id
# 0      355002
# 1      355002
# 2      355002
# 3      355002
# 4      355002

# %%
# evaluate each column null values
null_counts = cb_df.isnull().sum()
print("Null values in each column:")
print(null_counts)
# Out:
# Null values in each column:
# strategy_code                   0
# future_id                       0
# region                          0
# time_period                     0
# difference_variable             0
# variable_value_baseline    110512
# variable_value_pathway          0
# difference_value           110512
# variable                        0
# value                       98068
# primary_id                      0
# dtype: int64
