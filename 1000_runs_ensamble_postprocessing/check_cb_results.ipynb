# %%
import pandas as pd
import os

# %%
# Set up paths
SCRIPT_DIR_PATH = os.getcwd()
CW_DIR_PATH = os.path.join(SCRIPT_DIR_PATH, "cw")
DATA_DIR_PATH = os.path.join(SCRIPT_DIR_PATH, "data")
ENSEMBLE_DIR_PATH = os.path.join(DATA_DIR_PATH, "ensemble_data")
run_id = "2025-09-18t09;19;22.726476"
RUN_DIR_PATH = os.path.join(ENSEMBLE_DIR_PATH, f"sisepuede_summary_results_run_sisepuede_run_{run_id}")

# %%
cb_df = pd.read_csv(os.path.join(RUN_DIR_PATH, f"cba_la_{run_id}_tornado.csv"))
# cb_df = pd.read_csv(os.path.join(RUN_DIR_PATH, f"combined_cb_results_{run_id}.csv"))
cb_df.head()
# Out:
#        strategy_code  future_id     region  time_period   difference_variable  \
# 0  AGRC:DEC_CH4_RICE        0.0  louisiana          7.0  pop_unimproved_rural
# 1  AGRC:DEC_CH4_RICE        0.0  louisiana          8.0  pop_unimproved_rural
# 2  AGRC:DEC_CH4_RICE        0.0  louisiana          9.0  pop_unimproved_rural
# 3  AGRC:DEC_CH4_RICE        0.0  louisiana         10.0  pop_unimproved_rural
# 4  AGRC:DEC_CH4_RICE        0.0  louisiana         11.0  pop_unimproved_rural
#
#    variable_value_baseline  variable_value_pathway  difference_value  \
# 0            299091.209054           299091.209054               0.0
# 1            294340.078493           294340.078493               0.0
# 2            289474.711388           289474.711388               0.0
# 3            284494.629299           284494.629299               0.0
# 4            279403.968085           279403.968085               0.0
#
#                                         variable  value
# 0  cb:wali:technical_cost:sanitation:unimp_rural    0.0
# 1  cb:wali:technical_cost:sanitation:unimp_rural    0.0
# 2  cb:wali:technical_cost:sanitation:unimp_rural    0.0
# 3  cb:wali:technical_cost:sanitation:unimp_rural   -0.0
# 4  cb:wali:technical_cost:sanitation:unimp_rural   -0.0

# %%
#print shape
cb_df.shape
# Out:
# (401056, 10)

# %%
cb_df.future_id.nunique()
# Out:
# 1

# %%
# evaluate each column null values
null_counts = cb_df.isnull().sum()
print("Null values in each column:")
print(null_counts)
# Out:
# Null values in each column:
# strategy_code                0
# future_id                    0
# region                       0
# time_period                  0
# difference_variable          0
# variable_value_baseline    900
# variable_value_pathway       0
# difference_value           900
# variable                     0
# value                      828
# dtype: int64

# %%
null_baseline = cb_df[cb_df['variable_value_baseline'].isnull()]
null_baseline
# Out:
#                     strategy_code  future_id     region  time_period  \
# 353992             FGTV:DEC_LEAKS        0.0  louisiana         25.0
# 353993             FGTV:DEC_LEAKS        0.0  louisiana         26.0
# 353994             FGTV:DEC_LEAKS        0.0  louisiana         27.0
# 353995             FGTV:DEC_LEAKS        0.0  louisiana         28.0
# 353996             FGTV:DEC_LEAKS        0.0  louisiana         29.0
# ...                           ...        ...        ...          ...
# 400838  PFLO:TWI_FULL_LEAP_SET_LC        0.0  louisiana         18.0
# 400839  PFLO:TWI_FULL_LEAP_SET_LC        0.0  louisiana         19.0
# 400840  PFLO:TWI_FULL_LEAP_SET_LC        0.0  louisiana         17.0
# 400841  PFLO:TWI_FULL_LEAP_SET_LC        0.0  louisiana         18.0
# 400842  PFLO:TWI_FULL_LEAP_SET_LC        0.0  louisiana         19.0
#
#                               difference_variable  variable_value_baseline  \
# 353992         energy_demand_enfu_total_fuel_coal                      NaN
# 353993         energy_demand_enfu_total_fuel_coal                      NaN
# 353994         energy_demand_enfu_total_fuel_coal                      NaN
# 353995         energy_demand_enfu_total_fuel_coal                      NaN
# 353996         energy_demand_enfu_total_fuel_coal                      NaN
# ...                                           ...                      ...
# 400838  energy_demand_enfu_total_fuel_natural_gas                      NaN
# 400839  energy_demand_enfu_total_fuel_natural_gas                      NaN
# 400840          energy_demand_enfu_total_fuel_oil                      NaN
# 400841          energy_demand_enfu_total_fuel_oil                      NaN
# 400842          energy_demand_enfu_total_fuel_oil                      NaN
#
#         variable_value_pathway  difference_value  \
# 353992                1.431869               NaN
# 353993                1.580035               NaN
# 353994                1.581415               NaN
# 353995                1.582892               NaN
# 353996                1.584469               NaN
# ...                        ...               ...
# 400838               11.077888               NaN
# 400839               11.038033               NaN
# 400840                2.010499               NaN
# 400841                1.968529               NaN
# 400842                1.936145               NaN
#
#                                             variable  value
# 353992                cb:fgtv:technical_cost:leaks:X    NaN
# 353993                cb:fgtv:technical_cost:leaks:X    NaN
# 353994                cb:fgtv:technical_cost:leaks:X    NaN
# 353995                cb:fgtv:technical_cost:leaks:X    NaN
# 353996                cb:fgtv:technical_cost:leaks:X    NaN
# ...                                              ...    ...
# 400838  cb:fgtv:technical_cost:leaks:X_shifted2023.0    NaN
# 400839  cb:fgtv:technical_cost:leaks:X_shifted2024.0    NaN
# 400840  cb:fgtv:technical_cost:leaks:X_shifted2022.0    NaN
# 400841  cb:fgtv:technical_cost:leaks:X_shifted2023.0    NaN
# 400842  cb:fgtv:technical_cost:leaks:X_shifted2024.0    NaN
#
# [900 rows x 10 columns]

# %%
null_baseline.variable.unique()  # Check unique future_ids with null baseline values
# Out:
# array(['cb:fgtv:technical_cost:leaks:X',
#        'cb:fgtv:technical_cost:flaring:X',
#        'cb:fgtv:technical_cost:leaks:X_shifted2022.0',
#        'cb:fgtv:technical_cost:leaks:X_shifted2023.0',
#        'cb:fgtv:technical_cost:leaks:X_shifted2024.0',
#        'cb:fgtv:technical_cost:flaring:X_shifted2022.0',
#        'cb:fgtv:technical_cost:flaring:X_shifted2023.0',
#        'cb:fgtv:technical_cost:flaring:X_shifted2024.0'], dtype=object)

# %%
# Check for -inf values in numeric columns
negative_inf_counts = (cb_df == -float('inf')).sum()
print("Negative infinity counts in each column:")
print(negative_inf_counts)
# Out:
# Negative infinity counts in each column:
# strategy_code              0
# future_id                  0
# region                     0
# time_period                0
# difference_variable        0
# variable_value_baseline    0
# variable_value_pathway     0
# difference_value           0
# variable                   0
# value                      0
# dtype: int64

# %%
# check the rows with -inf values in 'value' column
negative_inf_rows = cb_df[cb_df['value'] == -float('inf')]
print("Rows with -inf in 'value' column:")
negative_inf_rows
# Out:
# Rows with -inf in 'value' column:
# Empty DataFrame
# Columns: [strategy_code, future_id, region, time_period, difference_variable, variable_value_baseline, variable_value_pathway, difference_value, variable, value]
# Index: []

# %%
# # replace -inf with 0 in 'value' column
# cb_df['value'] = cb_df['value'].replace(-float('inf'), 0)
# cb_df['difference_value'] = cb_df['difference_value'].replace(-float('inf'), 0)

# %%
# Check for -inf values in numeric columns
negative_inf_counts = (cb_df == -float('inf')).sum()
print("Negative infinity counts in each column:")
print(negative_inf_counts)
# Out:
# Negative infinity counts in each column:
# strategy_code              0
# future_id                  0
# region                     0
# time_period                0
# difference_variable        0
# variable_value_baseline    0
# variable_value_pathway     0
# difference_value           0
# variable                   0
# value                      0
# dtype: int64

# %%
# replace all nans with 0
cb_df.fillna(0, inplace=True)
# Check if there are still any null values
null_counts_after_fill = cb_df.isnull().sum()
print("Null values after fillna:")
print(null_counts_after_fill)
# Out:
# Null values after fillna:
# strategy_code              0
# future_id                  0
# region                     0
# time_period                0
# difference_variable        0
# variable_value_baseline    0
# variable_value_pathway     0
# difference_value           0
# variable                   0
# value                      0
# dtype: int64

# %%
cb_df.future_id.nunique()
# Out:
# 1

# %%
# Save updated DataFrame
cb_df.to_csv(os.path.join(RUN_DIR_PATH, f"combined_cb_results_updated_{run_id}_tornado.csv"), index=False)
print(f"Updated DataFrame saved to combined_cb_results_updated_{run_id}.csv")
# Out:
# Updated DataFrame saved to combined_cb_results_updated_2025-09-18t09;19;22.726476.csv

# %% [markdown]
# ### Quick Validation

# %%
saved_df = pd.read_csv(os.path.join(RUN_DIR_PATH, f"combined_cb_results_updated_{run_id}_tornado.csv"))
saved_df.head()
# Out:
#        strategy_code  future_id     region  time_period   difference_variable  \
# 0  AGRC:DEC_CH4_RICE        0.0  louisiana          7.0  pop_unimproved_rural
# 1  AGRC:DEC_CH4_RICE        0.0  louisiana          8.0  pop_unimproved_rural
# 2  AGRC:DEC_CH4_RICE        0.0  louisiana          9.0  pop_unimproved_rural
# 3  AGRC:DEC_CH4_RICE        0.0  louisiana         10.0  pop_unimproved_rural
# 4  AGRC:DEC_CH4_RICE        0.0  louisiana         11.0  pop_unimproved_rural
#
#    variable_value_baseline  variable_value_pathway  difference_value  \
# 0            299091.209054           299091.209054               0.0
# 1            294340.078493           294340.078493               0.0
# 2            289474.711388           289474.711388               0.0
# 3            284494.629299           284494.629299               0.0
# 4            279403.968085           279403.968085               0.0
#
#                                         variable  value
# 0  cb:wali:technical_cost:sanitation:unimp_rural    0.0
# 1  cb:wali:technical_cost:sanitation:unimp_rural    0.0
# 2  cb:wali:technical_cost:sanitation:unimp_rural    0.0
# 3  cb:wali:technical_cost:sanitation:unimp_rural   -0.0
# 4  cb:wali:technical_cost:sanitation:unimp_rural   -0.0

# %%
print(cb_df.shape)
print(saved_df.shape)
# Out:
# (401056, 10)
# (401056, 10)

# %%
saved_df.future_id.nunique()
# Out:
# 1

# %%
saved_df.primary_id.nunique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/tc/7lgly1g56n1cclb6ls7rcwzr0000gn/T/ipykernel_16706/3836575627.py in ?()
# ----> 1 saved_df.primary_id.nunique()
#
# /opt/miniconda3/envs/ssp_la/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'primary_id'

# %% [markdown]
# ## Check wide file

# %%
wide_cb_df = pd.read_csv(os.path.join(RUN_DIR_PATH, "wide_cb_data_lhc_2025-08-28t15;29;22.344855.csv"))
wide_cb_df.head()
# Out:
#    primary_id  future_id        strategy_code    Year  air_pollution  \
# 0      402402          1  PFLO:ALL_LA_ACTIONS  2022.0   0.000000e+00
# 1      402402          1  PFLO:ALL_LA_ACTIONS  2023.0   0.000000e+00
# 2      402402          1  PFLO:ALL_LA_ACTIONS  2024.0   0.000000e+00
# 3      402402          1  PFLO:ALL_LA_ACTIONS  2025.0   9.695006e-16
# 4      402402          1  PFLO:ALL_LA_ACTIONS  2026.0   1.425974e-16
#
#      congestion  consumer_savings    crop_value  ecosystem_services  \
# 0  0.000000e+00          0.000000  0.000000e+00        0.000000e+00
# 1  0.000000e+00          0.000000  0.000000e+00        0.000000e+00
# 2  0.000000e+00          0.000000  0.000000e+00        0.000000e+00
# 3 -1.451481e-23          0.021749  0.000000e+00        6.959355e-12
# 4  0.000000e+00          0.043782  2.673078e-14        7.691665e-12
#
#    env_pollution  ...  human_health  ippu_value  land_pollution  lvst_value  \
# 0            0.0  ...      0.000000         0.0    0.000000e+00         0.0
# 1            0.0  ...      0.000000         0.0    0.000000e+00         0.0
# 2            0.0  ...      0.000000         0.0    0.000000e+00         0.0
# 3            0.0  ...      0.019772         0.0    0.000000e+00         0.0
# 4            0.0  ...      0.039802         0.0   -5.968559e-17         0.0
#
#     road_safety  sector_specific   system_cost  technical_cost  \
# 0  0.000000e+00     0.000000e+00  0.000000e+00        0.000000
# 1  0.000000e+00     0.000000e+00  0.000000e+00        0.000000
# 2  0.000000e+00     0.000000e+00  0.000000e+00        0.000000
# 3 -2.494771e-23     5.093170e-14  0.000000e+00       -0.021329
# 4  0.000000e+00    -5.563550e-14 -5.269051e-15       -0.072557
#
#    technical_savings  water_pollution
# 0       0.000000e+00              0.0
# 1       0.000000e+00              0.0
# 2       0.000000e+00              0.0
# 3       0.000000e+00              0.0
# 4       8.114148e-17              0.0
#
# [5 rows x 21 columns]

# %%
# check for null values in wide file
wide_null_counts = wide_cb_df.isnull().sum()
print("Null values in wide DataFrame:")
print(wide_null_counts)
# Out:
# Null values in wide DataFrame:
# primary_id            0
# future_id             0
# strategy_code         0
# Year                  0
# air_pollution         0
# congestion            0
# consumer_savings      0
# crop_value            0
# ecosystem_services    0
# env_pollution         0
# fuel_cost             0
# human_health          0
# ippu_value            0
# land_pollution        0
# lvst_value            0
# road_safety           0
# sector_specific       0
# system_cost           0
# technical_cost        0
# technical_savings     0
# water_pollution       0
# dtype: int64

# %%
# check for inf and -inf values in wide file
wide_negative_inf_counts = (wide_cb_df == -float('inf')).sum()
print("Negative infinity counts in wide DataFrame:")
print(wide_negative_inf_counts)
# Out:
# Negative infinity counts in wide DataFrame:
# primary_id            0
# future_id             0
# strategy_code         0
# Year                  0
# air_pollution         0
# congestion            0
# consumer_savings      0
# crop_value            0
# ecosystem_services    0
# env_pollution         0
# fuel_cost             0
# human_health          0
# ippu_value            0
# land_pollution        0
# lvst_value            0
# road_safety           0
# sector_specific       0
# system_cost           0
# technical_cost        0
# technical_savings     0
# water_pollution       0
# dtype: int64

# %%
wide_cb_df.future_id.nunique()
# Out:
# 991
